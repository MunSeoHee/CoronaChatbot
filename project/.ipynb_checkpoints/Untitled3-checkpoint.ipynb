# %%
import pandas as pd
import numpy as np
seoul_data=pd.read_csv("seoul.csv")

# %%
seoul_data= seoul_data.drop("Unnamed: 0",axis=1)

# %%
seoul_data
# Out:
#        도시    유입경로       확진 날짜    상태
# 0     마포구    리치웨이  2020-06-29  격리 중
# 1     노원구   해외 유입  2020-06-29  격리 중
# 2     마포구    리치웨이  2020-06-29  격리 중
# 3     금천구  확진자 접촉  2020-06-29  격리 중
# 4      기타    확인불가  2020-06-29  격리 중
# ...   ...     ...         ...   ...
# 1307  종로구  확진자 접촉  2020-01-31  격리해제
# 1308  마포구   해외 유입  2020-01-30  격리해제
# 1309  종로구  확진자 접촉  2020-01-30  격리해제
# 1310  중랑구   해외 유입  2020-01-30  격리해제
# 1311  강서구   해외 유입  2020-01-23  격리해제
#
# [1312 rows x 4 columns]

# %%
seoul_data[seoul_data.도시=="도봉구"]
# Out:
#        도시   유입경로       확진 날짜    상태
# 62    도봉구   어린이집  2020-06-24  격리 중
# 76    도봉구   어린이집  2020-06-23  격리 중
# 79    도봉구   어린이집  2020-06-23  격리 중
# 80    도봉구   어린이집  2020-06-23  격리 중
# 90    도봉구   어린이집  2020-06-21  격리 중
# ...   ...    ...         ...   ...
# 933   도봉구  해외 유입  2020-03-27  격리해제
# 966   도봉구  해외 유입  2020-03-24  격리해제
# 982   도봉구  해외 유입  2020-03-22  격리해제
# 1071  도봉구   동안교회  2020-03-14  격리해제
# 1213  도봉구     기타  2020-03-02  격리해제
#
# [62 rows x 4 columns]

# %%
seoul_data[seoul_data.도시=="도봉구"][:10]
